# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import datetime 
# %matplotlib inline
from pandas_datareader import data, wb

# %%
# importing plotly for interactive plots
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objects as go

# %%
#making a stock dictionary to store the dataframes of different stocks
stock={}
#making list of stock tickers
stock_list = ['ADANIPORTS.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'INFRATEL.NS', 'COALINDIA.NS', 'DRREDDY.NS', 'GAIL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'ITC.NS', 'ICICIBANK.NS', 'IOC.NS', 'INDUSINDBK.NS', 'LUPIN.NS', 'M&M.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SBIN.NS', 'TECHM.NS', 'UPL.NS', 'VEDL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS', 'RELIANCE.NS', 'TATAMOTORS.NS', 'TCS.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BPCL.NS', 'BAJAJ-AUTO.NS', 'BOSCHLTD.NS', 'CIPLA.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'EICHERMOT.NS', 'HCLTECH.NS', 'HINDUNILVR.NS', 'HDFC.NS', 'IBULHSGFIN.NS', 'KOTAKBANK.NS', 'MARUTI.NS', 'INFY.NS', 'LT.NS', 'SUNPHARMA.NS', 'TATASTEEL.NS', 'ULTRACEMCO.NS', '^NSEI', '^BSESN']

# %%
#making a dictionary with tickers and their coresponding company name
tickname = {'ticker': ['ADANIPORTS.NS', 'AUROPHARMA.NS', 'BAJFINANCE.NS', 'BHARTIARTL.NS', 'INFRATEL.NS', 'COALINDIA.NS', 'DRREDDY.NS', 'GAIL.NS', 'HINDALCO.NS', 'HINDPETRO.NS', 'ITC.NS', 'ICICIBANK.NS', 'IOC.NS', 'INDUSINDBK.NS', 'LUPIN.NS', 'M&M.NS', 'NTPC.NS', 'ONGC.NS', 'POWERGRID.NS', 'SBIN.NS', 'TECHM.NS', 'UPL.NS', 'VEDL.NS', 'WIPRO.NS', 'YESBANK.NS', 'ZEEL.NS', 'RELIANCE.NS', 'TATAMOTORS.NS', 'TCS.NS', 'AMBUJACEM.NS', 'ASIANPAINT.NS', 'AXISBANK.NS', 'BPCL.NS', 'BAJAJ-AUTO.NS', 'BOSCHLTD.NS', 'CIPLA.NS', 'HDFCBANK.NS', 'HEROMOTOCO.NS', 'EICHERMOT.NS', 'HCLTECH.NS', 'HINDUNILVR.NS', 'HDFC.NS', 'IBULHSGFIN.NS', 'KOTAKBANK.NS', 'MARUTI.NS', 'INFY.NS', 'LT.NS', 'SUNPHARMA.NS', 'TATASTEEL.NS', 'ULTRACEMCO.NS', '^NSEI', '^BSESN'],
'name': ['Adani Ports and Special Economic Zone Ltd.', 'Aurobindo Pharma Ltd.', 'Bajaj Finance Ltd.', 'Bharti Airtel Ltd.', 'Bharti Infratel Ltd.', 'Coal India Ltd.', 'Dr. Reddy’s Laboratories Ltd.', 'GAIL (India) Ltd.', 'Hindalco Industries Ltd.', 'Hindustan Petroleum Corporation Ltd.', 'I T C Ltd.', 'ICICI Bank Ltd.', 'Indian Oil Corporation Ltd.', 'IndusInd Bank Ltd.', 'Lupin Ltd.', 'Mahindra & Mahindra Ltd.', 'NTPC Ltd.', 'Oil & Natural Gas Corporation Ltd.', 'Power Grid Corporation of India Ltd.', 'State Bank of India', 'Tech Mahindra Ltd.', 'UPL Ltd.', 'Vedanta Ltd.', 'Wipro Ltd.', 'Yes Bank Ltd.', 'Zee Entertainment Enterprises Ltd.', 'Reliance Industries Limited', 'Tata Motors Limited', 'Tata Consultancy Services Limited', 'Ambuja Cements Limited', 'Asian Paints Limited', 'Axis Bank Limited', 'Bharat Petroleum Corporation Limited', 'Bajaj Auto Limited', 'Bosch Limited', 'Cipla Limited', 'HDFC Bank Limited ', 'Hero MotoCorp Limited', 'Eicher Motors Limited', 'HCL Technologies Limited', 'Hindustan Unilever Limited', 'Housing Development Finance Corporation Limited', 'Indiabulls Housing Finance Limited', 'Kotak Mahindra Bank Limited', 'Infosys Limited', 'Larsen & Toubro Limited', 'Maruti Suzuki India Limited', 'Sun Pharmaceutical Industries Limited', 'Tata Steel Limited', 'UltraTech Cement Limited', 'NIFTY 50', 'S&P BSE SENSEX ']}
    
#making dataframe from dictionary
comp_df = pd.DataFrame.from_dict(tickname)

# %%
#this for loop will make a separate dataframe for each stock getting data from yahoo finance
for df in stock_list:
    symbol = df
    data_source = 'yahoo'
    start_date = '2020-02-01'
    end_date = '2020-05-01'
    #now storing dataframe of each stock in the stock dictionary created earlier
    stock[df] = data.DataReader(symbol, data_source, start_date, end_date)
    stock[df] = stock[df][['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']] #changing positions of columns
    stock[df].name = df

# %%
stock['RELIANCE.NS'].head()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-02-03  1369.900024  1399.949951  1363.050049  1385.500000  1380.317139
# 2020-02-04  1400.000000  1432.500000  1397.800049  1426.400024  1421.064209
# 2020-02-05  1434.900024  1452.800049  1430.300049  1448.500000  1443.081421
# 2020-02-06  1454.099976  1467.000000  1440.099976  1457.800049  1452.346680
# 2020-02-07  1451.000000  1452.349976  1428.300049  1433.650024  1428.286987
#
#               Volume
# Date
# 2020-02-03  14040626
# 2020-02-04  11604666
# 2020-02-05   8444823
# 2020-02-06   7103715
# 2020-02-07   5581641

# %%
#making a function that calculates adjusted closing price between 20 Feb and 23 March and percent decline between them
def stk_adj_c(s):
    tick = s.name
    adj_c_20 = s.loc['2020-02-20']['Adj Close']
    adj_c_23 = s.loc['2020-03-23']['Adj Close']
    adj_c_d = ((adj_c_20-adj_c_23)/adj_c_20)*100
    return tick, adj_c_20, adj_c_23, adj_c_d

# %%
adj_c_rlc = stk_adj_c(stock['RELIANCE.NS'])
adj_c_rlc
# Out:
# ('RELIANCE.NS', 1480.391357421875, 880.742919921875, 40.50607526811675)

# %%
#making a fuction that will make a scatterplot of adjusted closing price of stocks that are passed
def plot_s(*args):
    fig = go.Figure() #creating a function of plotly offline
    for stock in args: #it will perform following for each stock in the passed argument
        fig.add_trace(go.Scatter(x=stock.index, y=stock['Adj Close'], mode='lines+markers', name=stock.name, showlegend=True))
    fig.show()

# %%
#making a function that will create a dataframe with the adjusted closing stock price of the stocks on 25th Feb and 24th March and the percentage decline that took place in betwwen them for the stocks that are passed as arguments
def df_s(*args):
    temp_adj_list = []
    for stock in args:
        adj_c = stk_adj_c(stock) #getting the adjusted closing price that stock
        temp_adj_list.append(adj_c) #adding the adjusted closing price for that stock in list created
    temp_df = pd.DataFrame(temp_adj_list, columns=['Ticker', 'Adj Close on 25th Feb', 'Adj Close on 24th March', 'Percent Decline'])
    temp_df_comp = temp_df.merge(comp_df, left_on='Ticker', right_on='ticker', how='left')
    return temp_df_comp[['ticker','name','Adj Close on 25th Feb', 'Adj Close on 24th March', 'Percent Decline']]

# %%
#plotting the impact of covid19 on stocks prices of companies in ENERGY industry
plot_s(stock['BPCL.NS'], stock['GAIL.NS'], stock['HINDPETRO.NS'], stock['IOC.NS'], stock['NTPC.NS'], stock['ONGC.NS'], stock['POWERGRID.NS'], stock['RELIANCE.NS'])
energy = df_s(stock['BPCL.NS'], stock['GAIL.NS'], stock['HINDPETRO.NS'], stock['IOC.NS'], stock['NTPC.NS'], stock['ONGC.NS'], stock['POWERGRID.NS'], stock['RELIANCE.NS'])
energy
# Out:
#          ticker                                  name  Adj Close on 25th Feb  \
# 0       BPCL.NS  Bharat Petroleum Corporation Limited             447.260834
# 1       GAIL.NS                     GAIL (India) Ltd.             119.300003
# 2  HINDPETRO.NS  Hindustan Petroleum Corporation Ltd.             212.647812
# 3        IOC.NS           Indian Oil Corporation Ltd.             107.032066
# 4       NTPC.NS                             NTPC Ltd.             110.651443
# 5       ONGC.NS    Oil & Natural Gas Corporation Ltd.              95.695648
# 6  POWERGRID.NS  Power Grid Corporation of India Ltd.             182.532135
# 7   RELIANCE.NS           Reliance Industries Limited            1480.391357
#
#    Adj Close on 24th March  Percent Decline
# 0               269.350006        39.777869
# 1                78.000000        34.618610
# 2               175.740417        17.356113
# 3                80.750000        24.555320
# 4                75.920708        31.387513
# ...

# %%
#plotting the impact of covid19 on stocks prices of companies in PHARMA industry
plot_s(stock['AUROPHARMA.NS'], stock['CIPLA.NS'], stock['DRREDDY.NS'], stock['LUPIN.NS'], stock['SUNPHARMA.NS'])
pharma = df_s(stock['AUROPHARMA.NS'], stock['CIPLA.NS'], stock['DRREDDY.NS'], stock['LUPIN.NS'], stock['SUNPHARMA.NS'])
pharma
# Out:
#           ticker                                   name  \
# 0  AUROPHARMA.NS                  Aurobindo Pharma Ltd.
# 1       CIPLA.NS                          Cipla Limited
# 2     DRREDDY.NS          Dr. Reddy’s Laboratories Ltd.
# 3       LUPIN.NS                             Lupin Ltd.
# 4   SUNPHARMA.NS  Sun Pharmaceutical Industries Limited
#
#    Adj Close on 25th Feb  Adj Close on 24th March  Percent Decline
# 0             599.750000               294.700012        50.862857
# 1             434.621124               375.250000        13.660432
# 2            3255.300049              2768.399902        14.957151
# 3             699.599976               592.150024        15.358770
# 4             404.950012               324.500000        19.866653

# %%
#plotting the impact of covid19 on stocks prices of companies in FINANCIAL SERVICES industry
plot_s(stock['AXISBANK.NS'], stock['BAJFINANCE.NS'], stock['HDFCBANK.NS'], stock['HDFC.NS'], stock['ICICIBANK.NS'], stock['IBULHSGFIN.NS'], stock['INDUSINDBK.NS'], stock['KOTAKBANK.NS'], stock['SBIN.NS'], stock['YESBANK.NS'])
finance = df_s(stock['AXISBANK.NS'], stock['BAJFINANCE.NS'], stock['HDFCBANK.NS'], stock['HDFC.NS'], stock['ICICIBANK.NS'], stock['IBULHSGFIN.NS'], stock['INDUSINDBK.NS'], stock['KOTAKBANK.NS'], stock['SBIN.NS'], stock['YESBANK.NS'])
finance
# Out:
#           ticker                                             name  \
# 0    AXISBANK.NS                                Axis Bank Limited
# 1  BAJFINANCE.NS                               Bajaj Finance Ltd.
# 2    HDFCBANK.NS                               HDFC Bank Limited
# 3        HDFC.NS  Housing Development Finance Corporation Limited
# 4   ICICIBANK.NS                                  ICICI Bank Ltd.
# 5  IBULHSGFIN.NS               Indiabulls Housing Finance Limited
# 6  INDUSINDBK.NS                               IndusInd Bank Ltd.
# 7   KOTAKBANK.NS                      Kotak Mahindra Bank Limited
# 8        SBIN.NS                              State Bank of India
# 9     YESBANK.NS                                    Yes Bank Ltd.
#
#    Adj Close on 25th Feb  Adj Close on 24th March  Percent Decline
# 0             744.299988               308.649994        58.531506
# 1            4869.258301              2266.149902        53.460060
# ...

# %%
#plotting the impact of covid19 on stocks prices of companies in IT industry
plot_s(stock['HCLTECH.NS'], stock['INFY.NS'], stock['TCS.NS'], stock['TECHM.NS'], stock['WIPRO.NS'])
it = df_s(stock['HCLTECH.NS'], stock['INFY.NS'], stock['TCS.NS'], stock['TECHM.NS'], stock['WIPRO.NS'])
it
# Out:
#        ticker                               name  Adj Close on 25th Feb  \
# 0  HCLTECH.NS           HCL Technologies Limited             608.049988
# 1     INFY.NS            Larsen & Toubro Limited             786.296692
# 2      TCS.NS  Tata Consultancy Services Limited            2134.880615
# 3    TECHM.NS                 Tech Mahindra Ltd.             818.455444
# 4    WIPRO.NS                         Wipro Ltd.             245.699997
#
#    Adj Close on 24th March  Percent Decline
# 0               417.149994        31.395444
# 1               519.380066        33.946045
# 2              1664.806274        22.018765
# 3               487.200012        40.473239
# 4               170.149994        30.748882

# %%
#plotting the impact of covid19 on stocks prices of companies in TELECOM industry
plot_s(stock['BHARTIARTL.NS'], stock['INFRATEL.NS'])
telecom = df_s(stock['BHARTIARTL.NS'], stock['INFRATEL.NS'])
telecom
# Out:
#           ticker                  name  Adj Close on 25th Feb  \
# 0  BHARTIARTL.NS    Bharti Airtel Ltd.             545.599976
# 1    INFRATEL.NS  Bharti Infratel Ltd.             220.696014
#
#    Adj Close on 24th March  Percent Decline
# 0               407.350006        25.339072
# 1               139.910736        36.604774

# %%
#plotting the impact of covid19 on stocks prices of companies in AUTOMOBILE industry
plot_s(stock['BAJAJ-AUTO.NS'], stock['BOSCHLTD.NS'], stock['EICHERMOT.NS'], stock['HEROMOTOCO.NS'], stock['M&M.NS'], stock['MARUTI.NS'], stock['TATAMOTORS.NS'])
automobile = df_s(stock['BAJAJ-AUTO.NS'], stock['BOSCHLTD.NS'], stock['EICHERMOT.NS'], stock['HEROMOTOCO.NS'], stock['M&M.NS'], stock['MARUTI.NS'], stock['TATAMOTORS.NS'])
automobile
# Out:
#           ticker                      name  Adj Close on 25th Feb  \
# 0  BAJAJ-AUTO.NS        Bajaj Auto Limited            2933.754395
# 1    BOSCHLTD.NS             Bosch Limited           14553.000000
# 2   EICHERMOT.NS     Eicher Motors Limited           18701.021484
# 3  HEROMOTOCO.NS     Hero MotoCorp Limited            2240.250000
# 4         M&M.NS  Mahindra & Mahindra Ltd.             524.849976
# 5      MARUTI.NS           Infosys Limited            6757.600098
# 6  TATAMOTORS.NS       Tata Motors Limited             158.500000
#
#    Adj Close on 24th March  Percent Decline
# 0              1935.550049        34.024810
# 1              8411.849609        42.198518
# 2             13705.900391        26.710418
# 3              1616.000000        27.865194
# 4               293.399994        44.098312
# 5              4220.350098        37.546614
# 6                66.199997        58.233440

# %%
#plotting the impact of covid19 on stocks prices of companies in METALS industry
plot_s(stock['COALINDIA.NS'], stock['HINDALCO.NS'], stock['TATASTEEL.NS'], stock['VEDL.NS'])
metals = df_s(stock['COALINDIA.NS'], stock['HINDALCO.NS'], stock['TATASTEEL.NS'], stock['VEDL.NS'])
metals
# Out:
#          ticker                      name  Adj Close on 25th Feb  \
# 0  COALINDIA.NS           Coal India Ltd.             164.512360
# 1   HINDALCO.NS  Hindalco Industries Ltd.             189.949997
# 2  TATASTEEL.NS        Tata Steel Limited             443.549988
# 3       VEDL.NS              Vedanta Ltd.             137.698441
#
#    Adj Close on 24th March  Percent Decline
# 0               127.849998        22.285475
# 1                87.900002        53.724663
# 2               271.149994        38.868222
# 3                62.650002        54.502025

# %%
#plotting the impact of covid19 on stocks prices of companies in CONSUMER GOODS industry
plot_s(stock['ASIANPAINT.NS'], stock['HINDUNILVR.NS'], stock['ITC.NS'])
consumer = df_s(stock['ASIANPAINT.NS'], stock['HINDUNILVR.NS'], stock['ITC.NS'])
consumer
# Out:
#           ticker                        name  Adj Close on 25th Feb  \
# 0  ASIANPAINT.NS        Asian Paints Limited            1834.878174
# 1  HINDUNILVR.NS  Hindustan Unilever Limited            2233.010254
# 2         ITC.NS                  I T C Ltd.             197.304886
#
#    Adj Close on 24th March  Percent Decline
# 0              1498.449951        18.335180
# 1              1857.026123        16.837546
# 2               146.754135        25.620628

# %%
#plotting the impact of covid19 on stocks prices of companies in CEMENT AND CEMENT PRODUCTS industry
plot_s(stock['AMBUJACEM.NS'], stock['ULTRACEMCO.NS'])
cement = df_s(stock['AMBUJACEM.NS'], stock['ULTRACEMCO.NS'])
cement
# Out:
#           ticker                      name  Adj Close on 25th Feb  \
# 0   AMBUJACEM.NS    Ambuja Cements Limited             201.660614
# 1  ULTRACEMCO.NS  UltraTech Cement Limited            4428.100098
#
#    Adj Close on 24th March  Percent Decline
# 0               143.194748        28.992209
# 1              3054.850098        31.012172

# %%
#plotting the impact of covid19 on stocks prices of companies in FERTILISERS & PESTICIDES industry 
plot_s(stock['UPL.NS'])
fertilizers = df_s(stock['UPL.NS'])
fertilizers
# Out:
#    ticker      name  Adj Close on 25th Feb  Adj Close on 24th March  \
# 0  UPL.NS  UPL Ltd.             584.349976               254.600006
#
#    Percent Decline
# 0        56.430219

# %%
#plotting the impact of covid19 on stocks prices of companies in CONSTRUCTION industry
plot_s(stock['LT.NS'])
construction = df_s(stock['LT.NS'])
construction
# Out:
#   ticker                         name  Adj Close on 25th Feb  \
# 0  LT.NS  Maruti Suzuki India Limited             1262.91333
#
#    Adj Close on 24th March  Percent Decline
# 0               714.049988        43.460096

# %%
#plotting the impact of covid19 on stocks prices of companies in SERVICE industry
plot_s(stock['ADANIPORTS.NS'])
service = df_s(stock['ADANIPORTS.NS'])
service
# Out:
#           ticker                                        name  \
# 0  ADANIPORTS.NS  Adani Ports and Special Economic Zone Ltd.
#
#    Adj Close on 25th Feb  Adj Close on 24th March  Percent Decline
# 0             366.796295               207.800003          43.3473

# %%
#plotting the impact of covid19 on stocks prices of companies in MEDIA & ENTERTAINMENT industry
plot_s(stock['ZEEL.NS'])
media = df_s(stock['ZEEL.NS'])
media
# Out:
#     ticker                                name  Adj Close on 25th Feb  \
# 0  ZEEL.NS  Zee Entertainment Enterprises Ltd.             256.799988
#
#    Adj Close on 24th March  Percent Decline
# 0                    122.0         52.49221

# %%
#plotting the impact of covid19 on NIFTY and SENSEX
Fig = go.Figure()
Fig.add_trace(go.Scatter(x=stock['^NSEI'].index, y=stock['^NSEI']['Adj Close'], mode='lines+markers', name=stock['^NSEI'].name, showlegend=True))
Fig.add_trace(go.Scatter(x=stock['^BSESN'].index, y=stock['^BSESN']['Adj Close'], mode='lines+markers', name=stock['^BSESN'].name, showlegend=True))
Fig.show()
overall = df_s(stock['^NSEI'], stock['^BSESN'])
overall
# Out:
#    ticker             name  Adj Close on 25th Feb  Adj Close on 24th March  \
# 0   ^NSEI         NIFTY 50           12080.849609              7610.250000
# 1  ^BSESN  S&P BSE SENSEX            41170.121094             25981.240234
#
#    Percent Decline
# 0        37.005672
# 1        36.892971
